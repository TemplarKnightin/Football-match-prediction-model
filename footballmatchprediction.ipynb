# %%
import pandas as pd
matches = pd.read_csv('/content/matches.csv',index_col=0)
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 0  2023-08-13  16:30  Premier League  Matchweek 1  Sun  Away      D  1.0  1.0
# 1  2023-08-19  15:00  Premier League  Matchweek 2  Sat  Home      W  3.0  1.0
# 2  2023-08-27  16:30  Premier League  Matchweek 3  Sun  Away      W  2.0  1.0
# 3  2023-09-03  14:00  Premier League  Matchweek 4  Sun  Home      W  3.0  0.0
# 4  2023-09-16  12:30  Premier League  Matchweek 5  Sat  Away      W  3.0  1.0
#
#         opponent  ...  match report  notes    sh  sot  dist   fk pk pkatt  \
# 0        Chelsea  ...  Match Report    NaN  13.0  1.0  17.8  0.0  0     0
# 1    Bournemouth  ...  Match Report    NaN  25.0  9.0  16.8  1.0  0     1
# 2  Newcastle Utd  ...  Match Report    NaN   9.0  4.0  17.2  1.0  0     0
# 3    Aston Villa  ...  Match Report    NaN  17.0  4.0  14.7  0.0  0     0
# 4         Wolves  ...  Match Report    NaN  16.0  5.0  15.8  0.0  0     0
#
#    season       team
# 0    2024  Liverpool
# 1    2024  Liverpool
# 2    2024  Liverpool
# 3    2024  Liverpool
# 4    2024  Liverpool
#
# [5 rows x 27 columns]

# %%
matches.shape
# Out:
# (2726, 27)

# %%
matches["team"].value_counts()
# Out:
# Crystal Palace              137
# Newcastle United            137
# Everton                     137
# Aston Villa                 137
# Tottenham Hotspur           137
# Brighton and Hove Albion    137
# Wolverhampton Wanderers     136
# Chelsea                     136
# Liverpool                   136
# Manchester United           136
# West Ham United             136
# Arsenal                     136
# Manchester City             135
# Leicester City              114
# Leeds United                114
# Southampton                 114
# Fulham                       99
# Burnley                      99
# Brentford                    97
# Sheffield United             61
# Nottingham Forest            60
# Bournemouth                  59
# Watford                      38
# Norwich City                 38
# West Bromwich Albion         38
# Luton Town                   22
# Name: team, dtype: int64

# %%
matches[matches["team"]=="Liverpool"]
# Out:
#           date   time            comp         round  day venue result   gf  \
# 0   2023-08-13  16:30  Premier League   Matchweek 1  Sun  Away      D  1.0
# 1   2023-08-19  15:00  Premier League   Matchweek 2  Sat  Home      W  3.0
# 2   2023-08-27  16:30  Premier League   Matchweek 3  Sun  Away      W  2.0
# 3   2023-09-03  14:00  Premier League   Matchweek 4  Sun  Home      W  3.0
# 4   2023-09-16  12:30  Premier League   Matchweek 5  Sat  Away      W  3.0
# ..         ...    ...             ...           ...  ...   ...    ...  ...
# 48  2021-05-08  20:15  Premier League  Matchweek 35  Sat  Home      W  2.0
# 49  2021-05-13  20:15  Premier League  Matchweek 34  Thu  Away      W  4.0
# 50  2021-05-16  16:30  Premier League  Matchweek 36  Sun  Away      W  2.0
# 51  2021-05-19  20:15  Premier League  Matchweek 37  Wed  Away      W  3.0
# 52  2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  2.0
#
#      ga        opponent  ...  match report  notes    sh  sot  dist   fk pk  \
# 0   1.0         Chelsea  ...  Match Report    NaN  13.0  1.0  17.8  0.0  0
# 1   1.0     Bournemouth  ...  Match Report    NaN  25.0  9.0  16.8  1.0  0
# 2   1.0   Newcastle Utd  ...  Match Report    NaN   9.0  4.0  17.2  1.0  0
# 3   0.0     Aston Villa  ...  Match Report    NaN  17.0  4.0  14.7  0.0  0
# 4   1.0          Wolves  ...  Match Report    NaN  16.0  5.0  15.8  0.0  0
# ..  ...             ...  ...           ...    ...   ...  ...   ...  ... ..
# 48  0.0     Southampton  ...  Match Report    NaN  14.0  6.0  13.6  0.0  0
# 49  2.0  Manchester Utd  ...  Match Report    NaN  17.0  8.0  14.9  0.0  0
# 50  1.0       West Brom  ...  Match Report    NaN  26.0  6.0  18.3  1.0  0
# 51  0.0         Burnley  ...  Match Report    NaN  20.0  3.0  16.2  1.0  0
# 52  0.0  Crystal Palace  ...  Match Report    NaN  19.0  5.0  14.7  1.0  0
#
#    pkatt  season       team
# 0      0    2024  Liverpool
# 1      1    2024  Liverpool
# 2      0    2024  Liverpool
# 3      0    2024  Liverpool
# 4      0    2024  Liverpool
# ..   ...     ...        ...
# 48     0    2021  Liverpool
# 49     0    2021  Liverpool
# 50     0    2021  Liverpool
# 51     0    2021  Liverpool
# 52     0    2021  Liverpool
#
# [136 rows x 27 columns]

# %%
matches["round"].value_counts()
# Out:
# Matchweek 1     80
# Matchweek 12    80
# Matchweek 22    80
# Matchweek 21    80
# Matchweek 2     80
# Matchweek 19    80
# Matchweek 16    80
# Matchweek 15    80
# Matchweek 14    80
# Matchweek 13    80
# Matchweek 20    80
# Matchweek 11    80
# Matchweek 6     80
# Matchweek 10    80
# Matchweek 3     80
# Matchweek 5     80
# Matchweek 4     80
# Matchweek 7     80
# Matchweek 8     80
# Matchweek 9     80
# Matchweek 18    78
# Matchweek 17    78
# Matchweek 23    70
# Matchweek 33    60
# Matchweek 32    60
# Matchweek 37    60
# Matchweek 36    60
# Matchweek 35    60
# Matchweek 28    60
# Matchweek 34    60
# Matchweek 25    60
# Matchweek 31    60
# Matchweek 30    60
# Matchweek 29    60
# Matchweek 27    60
# Matchweek 26    60
# Matchweek 24    60
# Matchweek 38    60
# Name: round, dtype: int64

# %%
matches["date"] = pd.to_datetime(matches["date"])
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                     float64
# ga                     float64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                       int64
# pkatt                    int64
# season                   int64
# team                    object
# dtype: object

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes
matches["opp_code"] = matches["opponent"].astype("category").cat.codes
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")
matches["day_code"] = matches["date"].dt.dayofweek
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 0  2023-08-13  16:30  Premier League   Matchweek 1  Sun  Away      D  1.0
# 1  2023-08-19  15:00  Premier League   Matchweek 2  Sat  Home      W  3.0
# 2  2023-08-27  16:30  Premier League   Matchweek 3  Sun  Away      W  2.0
# 3  2023-09-03  14:00  Premier League   Matchweek 4  Sun  Home      W  3.0
# 4  2023-09-16  12:30  Premier League   Matchweek 5  Sat  Away      W  3.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga        opponent  ...  dist   fk  pk  pkatt season              team  \
# 0   1.0         Chelsea  ...  17.8  0.0   0      0   2024         Liverpool
# 1   1.0     Bournemouth  ...  16.8  1.0   0      1   2024         Liverpool
# 2   1.0   Newcastle Utd  ...  17.2  1.0   0      0   2024         Liverpool
# 3   0.0     Aston Villa  ...  14.7  0.0   0      0   2024         Liverpool
# 4   1.0          Wolves  ...  15.8  0.0   0      0   2024         Liverpool
# ..  ...             ...  ...   ...  ...  ..    ...    ...               ...
# 38  4.0       Tottenham  ...  18.2  0.0   0      0   2021  Sheffield United
# 39  2.0  Crystal Palace  ...  13.4  1.0   0      0   2021  Sheffield United
# 40  0.0         Everton  ...  18.5  0.0   0      0   2021  Sheffield United
# 41  1.0   Newcastle Utd  ...  18.3  1.0   0      0   2021  Sheffield United
# 42  0.0         Burnley  ...  17.4  0.0   0      0   2021  Sheffield United
#
#    venue_code opp_code  hour  day_code
# 0           0        6    16         6
# 1           1        2    15         5
# 2           0       16    16         6
# 3           1        1    14         6
# 4           0       25    12         5
# ..        ...      ...   ...       ...
# 38          0       21    19         6
# 39          1        7    15         5
# 40          0        8    19         6
# 41          0       16    18         2
# 42          1        5    16         6
#
# [2726 rows x 31 columns]

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)
train = matches[matches["date"] < '2022-01-01']
test = matches[matches["date"] > '2022-01-01']
predictors = ["venue_code", "opp_code", "hour", "day_code"]
rf.fit(train[predictors], train["target"])
RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score
acc = accuracy_score(test["target"], preds)
combined = pd.DataFrame(dict(actual=test["target"], prediction=preds))
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction    0    1
# actual
# 0           780  190
# 1           438  186

# %%
from sklearn.metrics import precision_score
precision_score(test["target"], preds)
grouped_matches = matches.groupby("team")
group = grouped_matches.get_group("Liverpool")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]
rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result   gf  \
# 6  2020-10-04  19:15  Premier League   Matchweek 4  Sun  Away      L  2.0
# 7  2020-10-17  12:30  Premier League   Matchweek 5  Sat  Away      D  2.0
# 9  2020-10-24  20:00  Premier League   Matchweek 6  Sat  Home      W  2.0
# 11 2020-10-31  17:30  Premier League   Matchweek 7  Sat  Home      W  2.0
# 13 2020-11-08  16:30  Premier League   Matchweek 8  Sun  Away      D  1.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 26 2023-12-23  17:30  Premier League  Matchweek 18  Sat  Home      D  1.0
# 27 2023-12-26  17:30  Premier League  Matchweek 19  Tue  Away      W  2.0
# 28 2024-01-01  20:00  Premier League  Matchweek 20  Mon  Home      W  4.0
# 31 2024-01-21  16:30  Premier League  Matchweek 21  Sun  Away      W  4.0
# 34 2024-01-31  20:15  Premier League  Matchweek 22  Wed  Home      W  4.0
#
#      ga         opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 6   7.0      Aston Villa  ...         6       0    3.000000    1.333333
# 7   2.0          Everton  ...         5       0    2.333333    2.666667
# 9   1.0    Sheffield Utd  ...         5       1    2.333333    3.333333
# 11  1.0         West Ham  ...         5       1    2.000000    3.333333
# 13  1.0  Manchester City  ...         6       0    2.000000    1.333333
# ..  ...              ...  ...       ...     ...         ...         ...
# 26  1.0          Arsenal  ...         5       0    1.333333    0.333333
# 27  0.0          Burnley  ...         1       1    1.000000    0.666667
# 28  2.0    Newcastle Utd  ...         0       1    1.000000    0.333333
# 31  0.0      Bournemouth  ...         6       1    2.333333    1.000000
# 34  1.0          Chelsea  ...         2       1    3.333333    0.666667
#
#    sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 6   19.666667    5.666667    18.166667   0.333333    0.666667       0.666667
# 7   17.666667    7.000000    17.466667   0.666667    0.000000       0.000000
# 9   19.000000    8.000000    16.733333   1.000000    0.000000       0.000000
# 11  17.666667    7.000000    17.033333   1.333333    0.000000       0.000000
# 13  15.666667    5.666667    18.266667   1.333333    0.333333       0.333333
# ..        ...         ...          ...        ...         ...            ...
# 26  21.000000    6.000000    17.166667   0.000000    0.000000       0.000000
# 27  20.333333    4.333333    18.400000   0.333333    0.000000       0.000000
# 28  22.000000    7.000000    18.400000   0.333333    0.000000       0.000000
# 31  21.333333    8.333333    17.900000   0.333333    0.333333       0.666667
# 34  21.666667    9.666667    17.600000   0.000000    0.333333       0.666667
#
# [133 rows x 40 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
matches_rolling = matches_rolling.droplevel('team')
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2022-01-01']
    test = data[data["date"] < '2022-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd", "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham", "Wolverhampton Wanderers": "Wolves"}
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(map_values)
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])
merged
# Out:
#      actual_x  predicted_x       date                    team_x  \
# 0           0            0 2020-10-03  Brighton and Hove Albion
# 1           0            0 2020-10-18  Brighton and Hove Albion
# 2           0            0 2020-10-26  Brighton and Hove Albion
# 3           0            0 2020-11-01  Brighton and Hove Albion
# 4           0            0 2020-11-06  Brighton and Hove Albion
# ..        ...          ...        ...                       ...
# 309         0            0 2021-12-01   Wolverhampton Wanderers
# 310         0            0 2021-12-04   Wolverhampton Wanderers
# 311         0            0 2021-12-11   Wolverhampton Wanderers
# 312         1            1 2021-12-15   Wolverhampton Wanderers
# 313         0            0 2021-12-19   Wolverhampton Wanderers
#
#           opponent_x result_x new_team_x  actual_y  predicted_y  \
# 0            Everton        L   Brighton         1            1
# 1     Crystal Palace        D   Brighton         0            0
# 2          West Brom        D   Brighton         0            0
# 3          Tottenham        L   Brighton         1            1
# 4            Burnley        D   Brighton         0            0
# ..               ...      ...        ...       ...          ...
# 309          Burnley        D     Wolves         0            0
# 310        Liverpool        L     Wolves         1            1
# 311  Manchester City        L     Wolves         1            1
# 312         Brighton        W     Wolves         0            0
# 313          Chelsea        D     Wolves         0            0
#
#                        team_y opponent_y result_y new_team_y
# 0                     Everton   Brighton        W        NaN
# 1              Crystal Palace   Brighton        D        NaN
# 2        West Bromwich Albion   Brighton        D        NaN
# 3           Tottenham Hotspur   Brighton        W  Tottenham
# 4                     Burnley   Brighton        D        NaN
# ..                        ...        ...      ...        ...
# 309                   Burnley     Wolves        D        NaN
# 310                 Liverpool     Wolves        W        NaN
# 311           Manchester City     Wolves        W        NaN
# 312  Brighton and Hove Albion     Wolves        L   Brighton
# 313                   Chelsea     Wolves        D        NaN
#
# [314 rows x 13 columns]

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# 1    98
# 0     2
# Name: actual_x, dtype: int64

# %%
2/98
# Out:
# 0.02040816326530612
